# %% [markdown]
# # load libraries and data

# %%
from torch import nn
import torch
from torch import tensor 
from torch.autograd import Variable
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
from pytorch_tabnet.tab_model import TabNetClassifier, TabNetRegressor
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import KFold
import torch
import itertools
from pytorch_tabnet.tab_model import TabNetClassifier
from sklearn.metrics import roc_auc_score, accuracy_score
from tqdm.notebook import tqdm
from pathlib import Path
import os

total_out = Path(os.getcwd()+'/Statin_preprocess.csv')
total_data= pd.read_csv(total_out)

target ='mace'
unused_feat = ['interval_statin']

# mri feature가 시작하는 column의 index 구하기
# np.where의 결과값이 array에 들어가기 때문에 방금 계산해 넣어놓은 [0]번째 값을 가져온다.
start_features_index = np.where(total_data.columns.values == "group_after_detail_1")[0][0]
features = list(total_data.columns[start_features_index:])

print(total_data.shape)
print(features)

Num_feat = len(features)
# Out:
# (122398, 27)
# ['group_after_detail_1', 'statin_drug', 'AGE', 'SEX', 'HTN', 'ICDHTN', 'trt_ICD_DM', 'DM', 'BMI', 'WAIST', 'BP_HIGH', 'BP_LWST', 'BLDS', 'TOT_CHOLE', 'TRIGLYCERIDE', 'HDL_CHOLE', 'LDL_CHOLE', 'HMG', 'smoking', 'econo', 'drinking', 'HMG.1', 'LDL_CHOLE.1', 'current_ascvd', 'risk']

# %%
def feature(Num_feat, clf, test_data_processed, features):
    importance =clf.feature_importances_
    #plt.plot(importance)
    #plt.show()
    labels_importance=importance.argsort()[::-1]

    importance_sort = np.sort(importance)[::-1]

    feat_name_sort=test_data_processed[features].columns[labels_importance]
    important_features = pd.DataFrame() 
    
    for i in range (Num_feat):
        feature = pd.DataFrame([[feat_name_sort[i],importance_sort[i]]], columns = ['feature name', 'ratio'])
        important_features=pd.concat([important_features,feature])

    return important_features.reset_index(drop=True)

# %% [markdown]
# # Finding best parameters

# %%
# Augmented
import torch
import itertools
from sklearn.metrics import confusion_matrix
from pytorch_tabnet.tab_model import TabNetClassifier
from sklearn.metrics import roc_auc_score, accuracy_score
from tqdm.notebook import tqdm


def find_bestpar(train_data, test_data, features):
    
    valid_cut = (int)(len(train_data)*0.8)
    for_Train = train_data[:valid_cut]
    for_Validation = train_data[valid_cut:]
    
    """train data 생성"""
    X_train = for_Train[features].values
    Y_train = for_Train[target].values
    
    """valid data 생성"""
    X_valid = for_Validation[features].values
    Y_valid = for_Validation[target].values
    
    """test data 생성"""
    X_test = test_data[features].values
    Y_test = test_data[target].values
    
    print(len(X_train), len(X_valid), len(X_test))            
    
    # Store maximum auc
    max_auc= 0
    # Store maximum hypterparameter set
    max_hy = []
    
    """
    # define hyperparameter space : learning rate, 
    n_ = [4,8,16]                              # 
    lr_ = [2e-2, 1e-2, 5e-3, 2e-3, 1e-3, 1e-4] # learning rate
    w_ = [0.01, 0.001, 0.0001]                 # weight decay
    g_ = [0.95, 0.99, 0.9]                     # scheduler params - gamma
    ss_ = [10, 20, 30]                         # scheduler params - step_size
    """
    # Orginal hyperparameter space 
    
    # define hyperparameter space (quick version)
    n_ = [4,16]
    lr_ = [2e-2,1e-3]
    w_ = [0.01,0.001]
    g_ = [0.95,0.99]
    ss_ = [10,30]
    
    all_ = [n_, lr_, w_, g_, ss_]
    h_space = [s for s in itertools.product(*all_)]
    
    print("start training")
    count=0
    for hy in tqdm(h_space):
        count = count + 1
        clf = TabNetClassifier(n_a = hy[0],
                                n_d = hy[0],
                                optimizer_params = dict(lr=hy[1], weight_decay=hy[2]),
                                scheduler_params={"step_size":hy[4], "gamma":hy[3]},
                                scheduler_fn=torch.optim.lr_scheduler.StepLR,
                                verbose=0)

        clf.fit(X_train, Y_train, eval_set=[(X_train, Y_train), (X_valid, Y_valid)], 
                    eval_name=['train', 'valid'], eval_metric=['auc'],
                    max_epochs=200 , patience=20)
       
        preds_acc = clf.predict(X_test)
        preds_prob = clf.predict_proba(X_test)
        test_auc = roc_auc_score(y_score=preds_prob[:,1], y_true=Y_test)
        test_acc = accuracy_score(preds_acc, Y_test)
            
        print('Valid score: %2f'% clf.best_cost, 'Test AUC: %.3f%%'%test_auc, 'Test ACC: %.3f%%'%test_acc)
    
        if np.mean(test_auc)>max_auc:
            print("Find new maximum test AUC!!\n")
            max_hy = hy
            max_valid_score = clf.best_cost
            max_auc = test_auc
            max_acc = test_acc
    
    return clf, max_hy, max_valid_score, max_auc, max_acc, preds_prob

# %%
def preprocessing (total_data):
    total_data_processed= total_data.fillna(0).reset_index(drop=True)
    
    # frac: 전체 row 중 몇 %를 반환할 지 결정 -> frac=1을 설정해서 모든 데이터를 반환
    # random_state: 추후 이것과 동일한 샘플링을 재현하기 위함
    # sample: 데이터에서 임의의 샘플 선정 -> frac=1이면 전체 data의 순서만 임의로 바뀜
    total_data_processed = total_data_processed.sample(frac=1,random_state=2020).reset_index(drop=True)
    
    print("done preprocessing")
    return total_data_processed

total_data = preprocessing(total_data)
print(len(total_data))
# Out:
# done preprocessing
# 122398

# %%
train_cut = (int)(len(total_data)*0.8)
#print(train_cut)                 

train_data = total_data[:train_cut] 
test_data = total_data[train_cut:] 
#print(len(train_data), len(test_data))

# %%
class model():
    def __init__(self, train_data, test_data, Num_feat, features):
        clf, max_hy, max_valid_score, max_test_auc, max_test_acc, preds_prob = find_bestpar(train_data, test_data, features)    
    
        self.train_data = train_data
        self.test_data = test_data
        self.preds_prob = preds_prob 
        self.max_hy = max_hy
        self.test_auc = max_test_auc
        self.test_acc = max_test_acc
        self.valid_score = max_valid_score
        self.clf = clf
        self.features = features

# %%
TabNet_mace_model = model(train_data, test_data, Num_feat, features)
# Out:
# 78334 19584 24480
# start training
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=32.0), HTML(value='')))
# Early stopping occurred at epoch 30 with best_epoch = 10 and best_valid_auc = 0.71519
# Best weights from best epoch are automatically used!
# Valid score: 0.715194 Test AUC: 0.725% Test ACC: 0.960%
# Find new maximum test AUC!!
#
#
# Early stopping occurred at epoch 30 with best_epoch = 10 and best_valid_auc = 0.71512
# Best weights from best epoch are automatically used!
# Valid score: 0.715120 Test AUC: 0.726% Test ACC: 0.960%
# Find new maximum test AUC!!
#
#
# Early stopping occurred at epoch 42 with best_epoch = 22 and best_valid_auc = 0.71889
# Best weights from best epoch are automatically used!
# Valid score: 0.718895 Test AUC: 0.728% Test ACC: 0.960%
# Find new maximum test AUC!!
#
#
# Early stopping occurred at epoch 30 with best_epoch = 10 and best_valid_auc = 0.71512
# Best weights from best epoch are automatically used!
# Valid score: 0.715120 Test AUC: 0.726% Test ACC: 0.960%
#
# Early stopping occurred at epoch 38 with best_epoch = 18 and best_valid_auc = 0.72424
# Best weights from best epoch are automatically used!
# Valid score: 0.724244 Test AUC: 0.726% Test ACC: 0.960%
#
# Early stopping occurred at epoch 38 with best_epoch = 18 and best_valid_auc = 0.72424
# Best weights from best epoch are automatically used!
# Valid score: 0.724235 Test AUC: 0.727% Test ACC: 0.960%
#
# Early stopping occurred at epoch 42 with best_epoch = 22 and best_valid_auc = 0.7254
# Best weights from best epoch are automatically used!
# Valid score: 0.725401 Test AUC: 0.728% Test ACC: 0.960%
#
# Early stopping occurred at epoch 38 with best_epoch = 18 and best_valid_auc = 0.72424
# Best weights from best epoch are automatically used!
# Valid score: 0.724235 Test AUC: 0.727% Test ACC: 0.960%
#
# Early stopping occurred at epoch 66 with best_epoch = 46 and best_valid_auc = 0.72598
# Best weights from best epoch are automatically used!
# Valid score: 0.725977 Test AUC: 0.731% Test ACC: 0.960%
# Find new maximum test AUC!!
#
#
# Early stopping occurred at epoch 64 with best_epoch = 44 and best_valid_auc = 0.72494
# Best weights from best epoch are automatically used!
# Valid score: 0.724939 Test AUC: 0.730% Test ACC: 0.960%
#
# Early stopping occurred at epoch 66 with best_epoch = 46 and best_valid_auc = 0.72702
# Best weights from best epoch are automatically used!
# Valid score: 0.727024 Test AUC: 0.729% Test ACC: 0.960%
#
# Early stopping occurred at epoch 67 with best_epoch = 47 and best_valid_auc = 0.72524
# Best weights from best epoch are automatically used!
# Valid score: 0.725239 Test AUC: 0.731% Test ACC: 0.960%
#
# Early stopping occurred at epoch 131 with best_epoch = 111 and best_valid_auc = 0.7192
# Best weights from best epoch are automatically used!
# Valid score: 0.719200 Test AUC: 0.719% Test ACC: 0.960%
#
# Early stopping occurred at epoch 118 with best_epoch = 98 and best_valid_auc = 0.72129
# Best weights from best epoch are automatically used!
# Valid score: 0.721286 Test AUC: 0.725% Test ACC: 0.960%
#
# Early stopping occurred at epoch 85 with best_epoch = 65 and best_valid_auc = 0.71736
# Best weights from best epoch are automatically used!
# Valid score: 0.717365 Test AUC: 0.714% Test ACC: 0.960%
#
# Early stopping occurred at epoch 75 with best_epoch = 55 and best_valid_auc = 0.7192
# Best weights from best epoch are automatically used!
# Valid score: 0.719196 Test AUC: 0.720% Test ACC: 0.960%
#
# Early stopping occurred at epoch 33 with best_epoch = 13 and best_valid_auc = 0.72004
# Best weights from best epoch are automatically used!
# Valid score: 0.720038 Test AUC: 0.726% Test ACC: 0.960%
#
# Early stopping occurred at epoch 43 with best_epoch = 23 and best_valid_auc = 0.72305
# Best weights from best epoch are automatically used!
# Valid score: 0.723048 Test AUC: 0.726% Test ACC: 0.960%
#
# Early stopping occurred at epoch 33 with best_epoch = 13 and best_valid_auc = 0.71821
# Best weights from best epoch are automatically used!
# Valid score: 0.718210 Test AUC: 0.728% Test ACC: 0.960%
#
# Early stopping occurred at epoch 43 with best_epoch = 23 and best_valid_auc = 0.72305
# Best weights from best epoch are automatically used!
# Valid score: 0.723048 Test AUC: 0.726% Test ACC: 0.960%
#
# Early stopping occurred at epoch 33 with best_epoch = 13 and best_valid_auc = 0.72321
# Best weights from best epoch are automatically used!
# Valid score: 0.723210 Test AUC: 0.726% Test ACC: 0.960%
#
# Early stopping occurred at epoch 33 with best_epoch = 13 and best_valid_auc = 0.72141
# Best weights from best epoch are automatically used!
# Valid score: 0.721406 Test AUC: 0.725% Test ACC: 0.960%
#
# Early stopping occurred at epoch 34 with best_epoch = 14 and best_valid_auc = 0.72235
# Best weights from best epoch are automatically used!
# Valid score: 0.722348 Test AUC: 0.727% Test ACC: 0.960%
#
# Early stopping occurred at epoch 33 with best_epoch = 13 and best_valid_auc = 0.72141
# Best weights from best epoch are automatically used!
# Valid score: 0.721406 Test AUC: 0.725% Test ACC: 0.960%
#
# Early stopping occurred at epoch 61 with best_epoch = 41 and best_valid_auc = 0.72991
# Best weights from best epoch are automatically used!
# Valid score: 0.729906 Test AUC: 0.731% Test ACC: 0.960%
#
# Early stopping occurred at epoch 61 with best_epoch = 41 and best_valid_auc = 0.72634
# Best weights from best epoch are automatically used!
# Valid score: 0.726338 Test AUC: 0.728% Test ACC: 0.960%
#
# Early stopping occurred at epoch 61 with best_epoch = 41 and best_valid_auc = 0.72648
# Best weights from best epoch are automatically used!
# Valid score: 0.726476 Test AUC: 0.729% Test ACC: 0.960%
#
# Early stopping occurred at epoch 51 with best_epoch = 31 and best_valid_auc = 0.72499
# Best weights from best epoch are automatically used!
# Valid score: 0.724987 Test AUC: 0.727% Test ACC: 0.960%
#
# Early stopping occurred at epoch 73 with best_epoch = 53 and best_valid_auc = 0.71586
# Best weights from best epoch are automatically used!
# Valid score: 0.715856 Test AUC: 0.713% Test ACC: 0.960%
#
# Early stopping occurred at epoch 112 with best_epoch = 92 and best_valid_auc = 0.72355
# Best weights from best epoch are automatically used!
# Valid score: 0.723548 Test AUC: 0.718% Test ACC: 0.960%
#
# Early stopping occurred at epoch 74 with best_epoch = 54 and best_valid_auc = 0.71482
# Best weights from best epoch are automatically used!
# Valid score: 0.714816 Test AUC: 0.720% Test ACC: 0.960%
#
# Early stopping occurred at epoch 87 with best_epoch = 67 and best_valid_auc = 0.7224
# Best weights from best epoch are automatically used!
# Valid score: 0.722403 Test AUC: 0.718% Test ACC: 0.960%

# %%
print("<<Important Feature>>")
import_feat=feature(Num_feat, TabNet_mace_model.clf, TabNet_mace_model.test_data, TabNet_mace_model.features)
TabNet_mace_model.import_feat =  import_feat
import_feat
# Out:
# <<Important Feature>>
#             feature name     ratio
# 0                   risk  0.201608
# 1          current_ascvd  0.107460
# 2                    HTN  0.091597
# 3                    AGE  0.074498
# 4                    SEX  0.063318
# 5                  econo  0.057785
# 6                 ICDHTN  0.047698
# 7                     DM  0.039957
# 8                  HMG.1  0.034856
# 9                BP_LWST  0.032740
# 10                   HMG  0.029384
# 11             HDL_CHOLE  0.026534
# 12            trt_ICD_DM  0.023393
# 13  group_after_detail_1  0.022957
# 14               smoking  0.021404
# 15                  BLDS  0.020946
# 16           LDL_CHOLE.1  0.019594
# 17          TRIGLYCERIDE  0.017550
# 18             LDL_CHOLE  0.016590
# 19           statin_drug  0.013972
# 20              drinking  0.011461
# 21               BP_HIGH  0.008010
# 22                 WAIST  0.006775
# 23             TOT_CHOLE  0.006728
# 24                   BMI  0.003183

# %%
import dill

with open('./TabNet_mace_model.pkl', 'wb') as f:
    dill.dump(TabNet_mace_model, f)

# %%
import xgboost as xgb

"""
params = {
        'min_child_weight': [1, 5, 10],
        'gamma': [0.5, 1, 1.5, 2, 5],
        'subsample': [0.6, 0.8, 1.0],
        'colsample_bytree': [0.6, 0.8, 1.0],
        'max_depth': [3, 4, 5]
        }
"""

train_cut = (int)(len(total_data)*0.8)
#print(train_cut)         

train_data = total_data[:train_cut] 
test_data = total_data[train_cut:] 

X_train = train_data[features].values
y_train = train_data[target].values

X_test = test_data[features].values
y_test = test_data[target].values

xgb_model = xgb.XGBClassifier(objective="binary:logistic", random_state=42, eval_metric="auc")
xgb_model.fit(X_train, y_train)

y_pred = xgb_model.predict(X_test)

y_pred_prob = xgb_model.predict_proba(X_test)[:,1]

print(accuracy_score(y_test, y_pred))
print(roc_auc_score(y_test, y_pred_prob))
#print(xgb_model.best_params_)
# Out:
# /opt/conda/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# 0.9595179738562092
# 0.6890698582658147
