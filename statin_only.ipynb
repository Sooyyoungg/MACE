# %%
""" 전체 data 중 statin 복용 그룹 대상으로 mace 예측 """
# Out:
# ' 전체 data 중 statin 복용 그룹 대상으로 mace 예측 '

# %%
from torch import nn
import torch
from torch import tensor 
from torch.autograd import Variable
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
from pytorch_tabnet.tab_model import TabNetClassifier, TabNetRegressor
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import KFold
import torch
import itertools
from pytorch_tabnet.tab_model import TabNetClassifier
from sklearn.metrics import roc_auc_score, accuracy_score
from tqdm.notebook import tqdm
from pathlib import Path
import os

total_out = Path(os.getcwd()+'/Statin_preprocess.csv')
total_data= pd.read_csv(total_out)
print(type(total_data))
print(total_data.shape)

target ='mace'
unused_feat = ['interval_statin']

# mri feature가 시작하는 column의 index 구하기
# np.where의 결과값이 array에 들어가기 때문에 방금 계산해 넣어놓은 [0]번째 값을 가져온다.
start_features_index = np.where(total_data.columns.values == "group_after_detail_1")[0][0]
features = list(total_data.columns[start_features_index:])

print(len(features))
print(features)

Num_feat = 25
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (122398, 27)
# 25
# ['group_after_detail_1', 'statin_drug', 'AGE', 'SEX', 'HTN', 'ICDHTN', 'trt_ICD_DM', 'DM', 'BMI', 'WAIST', 'BP_HIGH', 'BP_LWST', 'BLDS', 'TOT_CHOLE', 'TRIGLYCERIDE', 'HDL_CHOLE', 'LDL_CHOLE', 'HMG', 'smoking', 'econo', 'drinking', 'HMG.1', 'LDL_CHOLE.1', 'current_ascvd', 'risk']

# %%
# statin column
statin_data = total_data[total_data['statin_drug']==1]
print(statin_data.shape)
# Out:
# (32125, 27)

# %%
statin_data
# Out:
#         interval_statin  mace  group_after_detail_1  statin_drug  AGE  SEX  \
# 6                  1646     0                    12            1   75    2
# 10                 1810     0                    10            1   75    2
# 12                 1166     0                    10            1   75    1
# 23                 1246     0                    10            1   75    2
# 29                 1145     0                    10            1   75    1
# ...                 ...   ...                   ...          ...  ...  ...
# 122374             1763     0                    10            1   60    2
# 122375             1513     0                     9            1   60    2
# 122378             1543     0                    10            1   60    2
# 122384             1573     0                    10            1   60    2
# 122385             1812     0                     9            1   60    2
#
#         HTN  ICDHTN  trt_ICD_DM  DM  ...  HDL_CHOLE  LDL_CHOLE        HMG  \
# 6         0       0           0   0  ...         41      136.0  12.500000
# 10        0       1           1   1  ...         40       73.0  14.000000
# 12        0       1           1   1  ...         51      109.0  12.000000
# 23        0       0           1   1  ...         68      180.0  11.699219
# 29        0       0           1   1  ...         40       86.0  15.898438
# ...     ...     ...         ...  ..  ...        ...        ...        ...
# 122374    0       1           0   0  ...         51       88.0  14.099609
# 122375    0       0           0   0  ...         79      195.0  12.298828
# 122378    0       1           0   0  ...         56      159.0  14.500000
# 122384    0       1           0   0  ...         67       92.0  12.798828
# 122385    0       0           0   0  ...         51      198.0  13.199219
#
#         smoking  econo  drinking      HMG.1  LDL_CHOLE.1  current_ascvd  \
# 6             0      3         1  12.500000        136.0              0
# 10            0      1         1  14.000000         73.0              0
# 12            0      2         1  12.000000        109.0              0
# 23            0      3         1  11.699219        180.0              0
# 29            0      1         1  15.898438         86.0              0
# ...         ...    ...       ...        ...          ...            ...
# 122374        0      3         1  14.099609         88.0              0
# 122375        0      3         1  12.298828        195.0              0
# 122378        0      2         1  14.500000        159.0              0
# 122384        0      3         1  12.798828         92.0              0
# 122385        0      1         1  13.199219        198.0              0
#
#             risk
# 6       0.141912
# 10      0.281002
# 12      0.414875
# 23      0.341367
# 29      0.382987
# ...          ...
# 122374  0.027272
# 122375  0.019180
# 122378  0.038093
# 122384  0.023437
# 122385  0.033475
#
# [32125 rows x 27 columns]

# %%
def feature(Num_feat, clf, test_data_processed, features):
    importance =clf.feature_importances_
    #plt.plot(importance)
    #plt.show()
    labels_importance=importance.argsort()[::-1] # argsort : 오름차순 정렬

    importance_sort = np.sort(importance)[::-1]

    feat_name_sort=test_data_processed[features].columns[labels_importance]
    important_features = pd.DataFrame() 
    
    for i in range (Num_feat):
        feature = pd.DataFrame([[feat_name_sort[i],importance_sort[i]]], columns = ['feature name', 'ratio'])
        important_features=pd.concat([important_features,feature])

    return important_features.reset_index(drop=True)

# %%
# Augmented
import torch
import itertools
from sklearn.metrics import confusion_matrix
from pytorch_tabnet.tab_model import TabNetClassifier
from sklearn.metrics import roc_auc_score, accuracy_score
from tqdm.notebook import tqdm


def find_bestpar(train_data, valid_data, test_data, features):
       
    """train data 생성"""
    X_train = train_data[features].values
    Y_train = train_data[target].values
    
    """valid data 생성"""
    X_valid = valid_data[features].values
    Y_valid = valid_data[target].values
    
    """test data 생성"""
    X_test = test_data[features].values
    Y_test = test_data[target].values
    
    print(len(X_train), len(X_valid), len(X_test))
    
    # Store maximum auc
    max_auc= 0
    # Store maximum hypterparameter set
    max_hy = []
    
    """
    # define hyperparameter space : learning rate, 
    n_ = [4,8,16]                              # 
    lr_ = [2e-2, 1e-2, 5e-3, 2e-3, 1e-3, 1e-4] # learning rate
    w_ = [0.01, 0.001, 0.0001]                 # weight decay
    g_ = [0.95, 0.99, 0.9]                     # scheduler params - gamma
    ss_ = [10, 20, 30]                         # scheduler params - step_size
    """
    # Orginal hyperparameter space 
    
    # define hyperparameter space (quick version)
    n_ = [4,16]
    lr_ = [2e-2,1e-3]
    w_ = [0.01,0.001]
    g_ = [0.95,0.99]
    ss_ = [10,30]
    
    all_ = [n_, lr_, w_, g_, ss_]
    h_space = [s for s in itertools.product(*all_)]
    
    print("start training")
    count=0
    for hy in tqdm(h_space):
        count = count + 1
        clf = TabNetClassifier(n_a = hy[0],
                                n_d = hy[0],
                                optimizer_params = dict(lr=hy[1], weight_decay=hy[2]),
                                scheduler_params={"step_size":hy[4], "gamma":hy[3]},
                                scheduler_fn=torch.optim.lr_scheduler.StepLR,
                                verbose=0)

        clf.fit(X_train, Y_train, eval_set=[(X_valid, Y_valid)], eval_metric=['auc'], max_epochs=200 , patience=20)
       
        preds_acc = clf.predict(X_test)
        preds_prob = clf.predict_proba(X_test)
        test_auc = roc_auc_score(y_score=preds_prob[:,1], y_true=Y_test)
        test_acc = accuracy_score(preds_acc, Y_test)
            
        print('Valid score: %2f'% clf.best_cost, 'Test AUC: %.3f%%'%test_auc, 'Test ACC: %.3f%%'%test_acc)
    
        if np.mean(test_auc)>max_auc:
            print("Find new maximum test AUC!!\n")
            max_hy = hy
            max_valid_score = clf.best_cost
            max_auc = test_auc
            max_acc = test_acc
    
    return clf, max_hy, max_valid_score, max_auc, max_acc

# %%
def preprocessing (total_data):
    total_data_processed= total_data.fillna(0).reset_index(drop=True)
    
    # frac: 전체 row 중 몇 %를 반환할 지 결정 -> frac=1을 설정해서 모든 데이터를 반환
    # random_state: 추후 이것과 동일한 샘플링을 재현하기 위함
    # sample: 데이터에서 임의의 샘플 선정 -> frac=1이면 전체 data의 순서만 임의로 바뀜
    total_data_processed = total_data_processed.sample(frac=1,random_state=2020).reset_index(drop=True)
    
    print("done preprocessing")
    return total_data_processed

statin_data = preprocessing(statin_data)
print(len(statin_data))
# Out:
# done preprocessing
# 32125

# %%
# mace 발병 유무에 따른 data 비율 분석
# 0 : 1 = 117622 : 4776
print(len(total_data))
print(len(total_data[total_data[target]==0]), len(total_data[total_data[target]==1]))

# 0 : 1 = 30501 : 1624 -> 비율 맞춰서 train, test data 나눠야 함
print(len(statin_data))
statin_mace_0 = statin_data[statin_data[target]==0] # statin 복용 o & mace 발병 x
statin_mace_1 = statin_data[statin_data[target]==1] # statin 복용 o & mace 발병 o
print(len(statin_mace_0), len(statin_mace_1))
# Out:
# 122398
# 117622 4776
# 32125
# 30501 1624

# %%
# mace 값에 따라서 각각 train : valid : test = 6 : 2 : 2 로 나누도록
mace_0_train_cut = (int)(len(statin_mace_0)*0.6) #24400
mace_0_valid_cut = (int)(len(statin_mace_0)*0.8) #24400

statin_mace_0_train = statin_mace_0[:mace_0_train_cut]
statin_mace_0_valid = statin_mace_0[mace_0_train_cut:mace_0_valid_cut]
statin_mace_0_test = statin_mace_0[mace_0_valid_cut:]
print(len(statin_mace_0_train), len(statin_mace_0_valid), len(statin_mace_0_test))

mace_1_train_cut = (int)(len(statin_mace_1)*0.6) #1299
mace_1_valid_cut = (int)(len(statin_mace_1)*0.8) #1299

statin_mace_1_train = statin_mace_1[:mace_1_train_cut]
statin_mace_1_valid = statin_mace_1[mace_1_train_cut:mace_1_valid_cut]
statin_mace_1_test = statin_mace_1[mace_1_valid_cut:]
print(len(statin_mace_1_train), len(statin_mace_1_valid), len(statin_mace_1_test))

train_data = pd.concat([statin_mace_0_train, statin_mace_1_train])
valid_data = pd.concat([statin_mace_0_valid, statin_mace_1_valid])
test_data = pd.concat([statin_mace_0_test, statin_mace_1_test])

print(int(len(statin_data)*0.8), int(len(statin_data)*0.2))
print(len(train_data), len(valid_data), len(test_data))
# Out:
# 18300 6100 6101
# 974 325 325
# 25700 6425
# 19274 6425 6426

# %%
train_data
# Out:
#        interval_statin  mace  group_after_detail_1  statin_drug  AGE  SEX  \
# 0                 1364     0                    12            1   74    1
# 1                 1431     0                    12            1   74    2
# 3                 1791     0                    10            1   64    2
# 4                 1797     0                    10            1   62    2
# 5                 1747     0                     9            1   74    2
# ...                ...   ...                   ...          ...  ...  ...
# 19091              705     1                     1            1   70    1
# 19143              986     1                    10            1   71    1
# 19165              661     1                    10            1   67    1
# 19200              790     1                    12            1   67    1
# 19232             1616     1                    11            1   67    1
#
#        HTN  ICDHTN  trt_ICD_DM  DM  ...  HDL_CHOLE  LDL_CHOLE        HMG  \
# 0        0       1           0   0  ...         56      149.0  16.296875
# 1        0       1           0   0  ...        497      143.0  14.199219
# 3        0       1           0   0  ...         47      112.0  13.000000
# 4        0       0           1   1  ...         60       91.0  12.298828
# 5        0       0           0   0  ...         68      217.0  14.898438
# ...    ...     ...         ...  ..  ...        ...        ...        ...
# 19091    0       1           0   0  ...         46      111.0  13.500000
# 19143    0       1           1   1  ...         51       88.0  13.500000
# 19165    0       1           1   1  ...         55      123.0  13.298828
# 19200    0       1           0   0  ...         39       36.0  15.199219
# 19232    0       1           1   1  ...         86       68.0  15.699219
#
#        smoking  econo  drinking      HMG.1  LDL_CHOLE.1  current_ascvd  \
# 0            0      3         1  16.296875        149.0              0
# 1            0      2         1  14.199219        143.0              0
# 3            0      4         1  13.000000        112.0              0
# 4            0      4         1  12.298828         91.0              0
# 5            0      2         1  14.898438        217.0              0
# ...        ...    ...       ...        ...          ...            ...
# 19091        1      2         8  13.500000        111.0              1
# 19143        0      4         1  13.500000         88.0              0
# 19165        0      2         2  13.298828        123.0              0
# 19200        1      1         2  15.199219         36.0              0
# 19232        0      3         1  15.699219         68.0              0
#
#            risk
# 0      0.347138
# 1      0.114869
# 3      0.043556
# 4      0.079931
# 5      0.179291
# ...         ...
# 19091  0.294097
# 19143  0.279536
# 19165  0.314191
# 19200  0.185375
# 19232  0.156536
#
# [19274 rows x 27 columns]

# %%
clf, max_hy, max_valid_score, max_test_auc, max_test_acc = find_bestpar(train_data, valid_data, test_data, features)
# Out:
# 19274 6425 6426
# start training
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=32.0), HTML(value='')))
# Device used : cuda
#
# Early stopping occured at epoch 53 with best_epoch = 33 and best_val_0_auc = 0.73724
# Best weights from best epoch are automatically used!
# Valid score: 0.737238 Test AUC: 0.732% Test ACC: 0.949%
# Find new maximum test AUC!!
#
# Device used : cuda
#
# Early stopping occured at epoch 36 with best_epoch = 16 and best_val_0_auc = 0.73627
# Best weights from best epoch are automatically used!
# Valid score: 0.736270 Test AUC: 0.728% Test ACC: 0.949%
# Device used : cuda
#
# Early stopping occured at epoch 58 with best_epoch = 38 and best_val_0_auc = 0.73678
# Best weights from best epoch are automatically used!
# Valid score: 0.736784 Test AUC: 0.730% Test ACC: 0.949%
# Device used : cuda
#
# Early stopping occured at epoch 36 with best_epoch = 16 and best_val_0_auc = 0.73627
# Best weights from best epoch are automatically used!
# Valid score: 0.736270 Test AUC: 0.728% Test ACC: 0.949%
# Device used : cuda
#
# Early stopping occured at epoch 97 with best_epoch = 77 and best_val_0_auc = 0.74071
# Best weights from best epoch are automatically used!
# Valid score: 0.740710 Test AUC: 0.724% Test ACC: 0.949%
# Device used : cuda
#
# Early stopping occured at epoch 105 with best_epoch = 85 and best_val_0_auc = 0.74166
# Best weights from best epoch are automatically used!
# Valid score: 0.741663 Test AUC: 0.728% Test ACC: 0.949%
# Device used : cuda
#
# Early stopping occured at epoch 60 with best_epoch = 40 and best_val_0_auc = 0.73369
# Best weights from best epoch are automatically used!
# Valid score: 0.733687 Test AUC: 0.723% Test ACC: 0.949%
# Device used : cuda
#
# Early stopping occured at epoch 93 with best_epoch = 73 and best_val_0_auc = 0.73749
# Best weights from best epoch are automatically used!
# Valid score: 0.737488 Test AUC: 0.729% Test ACC: 0.949%
# Device used : cuda
#
# Early stopping occured at epoch 131 with best_epoch = 111 and best_val_0_auc = 0.7237
# Best weights from best epoch are automatically used!
# Valid score: 0.723701 Test AUC: 0.700% Test ACC: 0.949%
# Device used : cuda
#
# Early stopping occured at epoch 174 with best_epoch = 154 and best_val_0_auc = 0.73561
# Best weights from best epoch are automatically used!
# Valid score: 0.735607 Test AUC: 0.718% Test ACC: 0.949%
# Device used : cuda
#
# Early stopping occured at epoch 131 with best_epoch = 111 and best_val_0_auc = 0.72391
# Best weights from best epoch are automatically used!
# Valid score: 0.723913 Test AUC: 0.701% Test ACC: 0.949%
# Device used : cuda
#
# Early stopping occured at epoch 120 with best_epoch = 100 and best_val_0_auc = 0.72508
# Best weights from best epoch are automatically used!
# Valid score: 0.725082 Test AUC: 0.705% Test ACC: 0.949%
# Device used : cuda
#
# Early stopping occured at epoch 83 with best_epoch = 63 and best_val_0_auc = 0.67165
# Best weights from best epoch are automatically used!
# Valid score: 0.671648 Test AUC: 0.663% Test ACC: 0.950%
# Device used : cuda
#
# Early stopping occured at epoch 125 with best_epoch = 105 and best_val_0_auc = 0.69977
# Best weights from best epoch are automatically used!
# Valid score: 0.699766 Test AUC: 0.680% Test ACC: 0.949%
# Device used : cuda
#
# Early stopping occured at epoch 102 with best_epoch = 82 and best_val_0_auc = 0.70364
# Best weights from best epoch are automatically used!
# Valid score: 0.703641 Test AUC: 0.676% Test ACC: 0.949%
# Device used : cuda
#
# Early stopping occured at epoch 159 with best_epoch = 139 and best_val_0_auc = 0.70818
# Best weights from best epoch are automatically used!
# Valid score: 0.708179 Test AUC: 0.684% Test ACC: 0.949%
# Device used : cuda
#
# Early stopping occured at epoch 49 with best_epoch = 29 and best_val_0_auc = 0.73707
# Best weights from best epoch are automatically used!
# Valid score: 0.737068 Test AUC: 0.729% Test ACC: 0.949%
# Device used : cuda
#
# Early stopping occured at epoch 66 with best_epoch = 46 and best_val_0_auc = 0.73741
# Best weights from best epoch are automatically used!
# Valid score: 0.737408 Test AUC: 0.733% Test ACC: 0.949%
# Find new maximum test AUC!!
#
# Device used : cuda
#
# Early stopping occured at epoch 52 with best_epoch = 32 and best_val_0_auc = 0.73627
# Best weights from best epoch are automatically used!
# Valid score: 0.736270 Test AUC: 0.729% Test ACC: 0.949%
# Device used : cuda
#
# Early stopping occured at epoch 67 with best_epoch = 47 and best_val_0_auc = 0.73804
# Best weights from best epoch are automatically used!
# Valid score: 0.738043 Test AUC: 0.729% Test ACC: 0.949%
# Device used : cuda
#
# Early stopping occured at epoch 39 with best_epoch = 19 and best_val_0_auc = 0.74072
# Best weights from best epoch are automatically used!
# Valid score: 0.740720 Test AUC: 0.730% Test ACC: 0.949%
# Device used : cuda
#
# Early stopping occured at epoch 36 with best_epoch = 16 and best_val_0_auc = 0.74154
# Best weights from best epoch are automatically used!
# Valid score: 0.741544 Test AUC: 0.719% Test ACC: 0.949%
# Device used : cuda
#
# Early stopping occured at epoch 90 with best_epoch = 70 and best_val_0_auc = 0.74245
# Best weights from best epoch are automatically used!
# Valid score: 0.742451 Test AUC: 0.723% Test ACC: 0.949%
# Device used : cuda
#
# Early stopping occured at epoch 36 with best_epoch = 16 and best_val_0_auc = 0.74154
# Best weights from best epoch are automatically used!
# Valid score: 0.741544 Test AUC: 0.719% Test ACC: 0.949%
# Device used : cuda
#
# Early stopping occured at epoch 132 with best_epoch = 112 and best_val_0_auc = 0.73759
# Best weights from best epoch are automatically used!
# Valid score: 0.737594 Test AUC: 0.712% Test ACC: 0.949%
# Device used : cuda
#
# Early stopping occured at epoch 106 with best_epoch = 86 and best_val_0_auc = 0.73353
# Best weights from best epoch are automatically used!
# Valid score: 0.733535 Test AUC: 0.704% Test ACC: 0.949%
# Device used : cuda
#
# Early stopping occured at epoch 88 with best_epoch = 68 and best_val_0_auc = 0.73096
# Best weights from best epoch are automatically used!
# Valid score: 0.730955 Test AUC: 0.709% Test ACC: 0.949%
# Device used : cuda
#
# Early stopping occured at epoch 82 with best_epoch = 62 and best_val_0_auc = 0.72972
# Best weights from best epoch are automatically used!
# Valid score: 0.729719 Test AUC: 0.711% Test ACC: 0.949%
# Device used : cuda
#
# Early stopping occured at epoch 136 with best_epoch = 116 and best_val_0_auc = 0.68779
# Best weights from best epoch are automatically used!
# Valid score: 0.687787 Test AUC: 0.688% Test ACC: 0.949%
# Device used : cuda
#
# Early stopping occured at epoch 147 with best_epoch = 127 and best_val_0_auc = 0.70946
# Best weights from best epoch are automatically used!
# Valid score: 0.709465 Test AUC: 0.674% Test ACC: 0.948%
# Device used : cuda
#
# Early stopping occured at epoch 87 with best_epoch = 67 and best_val_0_auc = 0.67033
# Best weights from best epoch are automatically used!
# Valid score: 0.670331 Test AUC: 0.686% Test ACC: 0.949%
# Device used : cuda
#
# Early stopping occured at epoch 115 with best_epoch = 95 and best_val_0_auc = 0.69516
# Best weights from best epoch are automatically used!
# Valid score: 0.695160 Test AUC: 0.684% Test ACC: 0.948%

# %%
print("<<Important Feature>>")
import_feat=feature(Num_feat, clf, test_data, features)
import_feat.to_csv(f"MACE_features.csv")
import_feat
# Out:
# <<Important Feature>>
#             feature name     ratio
# 0                   risk  0.101457
# 1                  econo  0.100975
# 2                 ICDHTN  0.078692
# 3          current_ascvd  0.070003
# 4                    AGE  0.060751
# 5                    SEX  0.059474
# 6                    HTN  0.054965
# 7             trt_ICD_DM  0.039318
# 8              TOT_CHOLE  0.035541
# 9                BP_LWST  0.033831
# 10             LDL_CHOLE  0.031931
# 11          TRIGLYCERIDE  0.031016
# 12  group_after_detail_1  0.029984
# 13                    DM  0.029772
# 14                   HMG  0.027374
# 15               smoking  0.026925
# 16                 HMG.1  0.026816
# 17              drinking  0.024610
# 18           LDL_CHOLE.1  0.024487
# 19                 WAIST  0.023891
# 20                  BLDS  0.023425
# 21             HDL_CHOLE  0.021418
# 22                   BMI  0.016694
# 23               BP_HIGH  0.015846
# 24           statin_drug  0.010807

# %%
import xgboost as xgb

"""
params = {
        'min_child_weight': [1, 5, 10],
        'gamma': [0.5, 1, 1.5, 2, 5],
        'subsample': [0.6, 0.8, 1.0],
        'colsample_bytree': [0.6, 0.8, 1.0],
        'max_depth': [3, 4, 5]
        }
"""
# mace 값에 따라서 각각 train : test = 8 : 2 로 나누도록
mace_0_train_cut = (int)(len(statin_mace_0)*0.8) #24400

statin_mace_0_train = statin_mace_0[:mace_0_train_cut]
statin_mace_0_test = statin_mace_0[mace_0_train_cut:]
print(len(statin_mace_0_train), len(statin_mace_0_test))

mace_1_train_cut = (int)(len(statin_mace_1)*0.8) #1299

statin_mace_1_train = statin_mace_1[:mace_1_train_cut]
statin_mace_1_test = statin_mace_1[mace_1_train_cut:]
print(len(statin_mace_1_train), len(statin_mace_1_test))

train_data = pd.concat([statin_mace_0_train, statin_mace_1_train])
test_data = pd.concat([statin_mace_0_test, statin_mace_1_test])

print(int(len(statin_data)*0.8), int(len(statin_data)*0.2))
print(len(train_data), len(test_data))

X_train = train_data[features]
y_train = train_data[target]

X_test = test_data[features]
y_test = test_data[target]

xgb_model = xgb.XGBClassifier(objective="binary:logistic", random_state=42, eval_metric="auc")
xgb_model.fit(X_train, y_train)

y_pred = xgb_model.predict(X_test)

print(accuracy_score(y_test, y_pred))
#print(xgb_model.best_params_)
# Out:
# 24400 6101
# 1299 325
# 25700 6425
# 25699 6426
# 0.9474011826953004
